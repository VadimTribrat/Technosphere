# %%
import requests
from multiprocessing import Pool
import json
from lxml import etree, html as lhtml
import threading
import time
from tqdm import tqdm
import datetime
import pandas as pd
import threading

# %%
mutex = threading.Lock()

# %%
def get_page(url, n_attempts=5, t_sleep=1, header=None):
    for _ in range(n_attempts):
        if header is None:
            r = requests.get(url)
        else:
            r = requests.get(url, headers=header)
        if r.ok and r.status_code == 200:
            return r
        else:
            time.sleep(t_sleep)
    with mutex:
        print("Url: ", url, " isn't downloaded")
    return None

# %% [markdown]
# # 1) Get urls of cards

# %%
cards_url = []
page_num = 1
while len(cards_url) != 300:
    url = f"https://gg.deals/games/?sort=metascore&type=1&page={page_num}"
    text = get_page(url)
    if text is None:
        page_num += 1
        continue
    text = text.text
    query = '//div[@class="list-items shadow-box-small-lighter"]//a[@class="full-link"]'
    tree = lhtml.fromstring(text)
    for val in tree.xpath(query):
        cards_url.append("https://gg.deals" + val.attrib['href'])
        if len(cards_url) == 300:
            break
    print("Page_num: ", page_num, " len(pages) = ", len(cards_url))
    page_num += 1
# Out:
# Page_num:  1  len(pages) =  48
# Page_num:  2  len(pages) =  96
# Page_num:  3  len(pages) =  144
# Page_num:  4  len(pages) =  192
# Page_num:  5  len(pages) =  240
# Page_num:  6  len(pages) =  288
# Page_num:  7  len(pages) =  300

# %% [markdown]
# # 2) Get cards

# %%
cards = []
for val in tqdm(cards_url):
    text = get_page(val)
    if text is not None:
        text = text.text
        cards.append(text)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [03:05<00:00,  1.62it/s]

# %% [markdown]
# # 3) Parse cards

# %%
queries = {}
queries.update(name='//div[@class="game-heading"]//h1/text()')
queries.update(image='//div[@class="game-info-image"]//img/attribute::src')
queries.update(release_date='//div[@class="game-info-details-section game-info-details-section-release"]//p/text()')
queries.update(developer='//div[@class="game-info-details-section game-info-details-section-developer"]//p/text()')
queries.update(metacritic_score='//a[@class="score-circle score-metascore"]//span[@class="overlay"]/text()')
queries.update(user_score='//a[@class="score-circle score-userscore"]//span[@class="overlay"]/text()')
queries.update(review_label='//span[starts-with(@class, "reviews-label")]/text()')
queries.update(review_positive_pctg='//a[@class="score-grade"]//span[starts-with(@class, "reviews-label")]')
queries.update(review_count='//span[starts-with(@class, "reviews-label")]/span/text()')
queries.update(genres='//div[@class="tags-list badges-container"]/a/text()')
queries.update(tags='//div[@class="game-info-tags game-info-badges"]/h4[text()="Tags"]/..//a/text()')
queries.update(features='//div[@class="game-info-tags game-info-badges"]/h4[text()="Features"]/..//a/text()')
queries.update(platforms='//div[@class="game-info-details-section game-info-details-section-platforms"]//svg/attribute::title')
queries.update(wishlist_count='//div[@class="game-header-box"]//span[text()="Wishlist it"]/../..//span[@class="count"]/text()')
queries.update(alert_count='//div[@class="game-header-box"]//span[text()="Create alert"]/../..//span[@class="count"]/text()')
queries.update(owners_count='//div[@class="game-header-box"]//span[text()="Own it"]/../..//span[@class="count"]/text()')
queries.update(market_url='//a[@class="game-link-widget"]/attribute::href')
queries.update(dlcs='//section[@class="tab-menu-section offer-section"]//*[text()=" DLCs"]/../..//a[@class="full-link"]\
/attribute::href')
queries.update(packs='//section[@class="tab-menu-section offer-section"]//*[text()=" Packs"]/../..//a[@class="full-link"]\
/attribute::href')

# %%
def build_dict(card):
    dict_ = {}  
    tree = lhtml.fromstring(card)
    dict_['name'] = tree.xpath(queries['name'])[0][4:-3]
    val = tree.xpath(queries['image'])
    if val != []:
        dict_['image'] = val[0]
    val = tree.xpath(queries['market_url'])
    if val != []:
        dict_['market_url'] = val[0]
    val = tree.xpath(queries['wishlist_count'])
    if val != []:
        dict_['wishlist_count'] = val[0]
    val = tree.xpath(queries['alert_count'])
    if val != []:
        dict_['alert_count'] = val[0]
    val = tree.xpath(queries['owners_count'])
    if val != []:
        dict_['owners_count'] = val[0]
    val = tree.xpath(queries['release_date'])
    if val != []:
        dict_['release_date'] = val[0]
    val = tree.xpath(queries['developer'])
    if val != []:
        dict_['developer'] = val[0]
    val = tree.xpath(queries['metacritic_score'])
    if val != []:
        dict_['metacritic_score'] = val[0]
    val = tree.xpath(queries['user_score'])
    if val != []:
        dict_['user_score'] = tree.xpath(queries['user_score'])[0]
    val = tree.xpath(queries['review_label'])
    if val != []:
        dict_['review_label'] = val[0]
    try:
        dict_['review_positive_pctg'] = tree.xpath(queries['review_positive_pctg'])[0].attrib['title'].split('%')[0]
    except Exception:
        pass
    try:
        dict_['review_count'] = tree.xpath(queries['review_count'])[0].strip()[1:-1]
    except Exception:
        pass
    dict_['genres'] = tree.xpath(queries['genres'])
    dict_['tags'] = tree.xpath(queries['tags'])
    dict_['features'] = tree.xpath(queries['features'])
    dict_['platforms'] = tree.xpath(queries['platforms'])
    dict_['dlcs'] = tree.xpath(queries['dlcs'])
    dict_['packs'] = tree.xpath(queries['packs'])
    header_r = {'x-requested-with': 'XMLHttpRequest'}
    i = tree.xpath('//*[starts-with(@data-url, "/collection/single/?id")]')[0].attrib['data-url'].split('=')[-1]
    r = get_page(f"https://gg.deals/us/games/chartHistoricalData/{i}/?showKeyshops=1", header=header_r)
    if r is not None:
        d = r.json()
        if 'chartData' in d.keys():
            d = d['chartData']['deals']
            for_updates = []
            for i in range(len(d) - 1):
                for_updates.append(d[i + 1]['x'] - d[i]['x'])
            for i in range(len(d) - 1):
                d[i + 1]['ts'] = for_updates[i]
                d[i + 1]['price'] = d[i + 1]['y']
                del d[i + 1]['x']
                del d[i + 1]['y']
                del d[i + 1]['name']
            d[0]['ts'] = d[0]['x']
            d[0]['price'] = d[0]['y']
            del d[0]['x']
            del d[0]['y']
            del d[0]['name']
            dict_['price_history'] = d
    dict_ = {k:v for k, v in dict_.items() if v}
    #dict_ = json.dumps(dict_, indent=4)
    return dict_

# %%
parsed = []
for card in tqdm(cards):
    parsed.append(build_dict(card))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [02:23<00:00,  2.09it/s]

# %%
import gzip
import json
import codecs

from multiprocessing.dummy import Pool, Queue

queue = Queue()

for card in cards:
    queue.put(card)


def process_page_wrapper(i):
    with gzip.open('data/part_{:05d}.jsonl.gz'.format(i), mode='wb+') as f_json:
        f_json = codecs.getwriter('utf8')(f_json)

        while not queue.empty():
            try:
                record = build_dict(queue.get())
                record_str = json.dumps(record, ensure_ascii=False)
                print(record_str, file=f_json)
            except Exception as e:
                print(e)
            with lock:
                pbar.update(1)


with Pool(processes=8) as pool, tqdm(total=queue.qsize()) as pbar:
    lock = pbar.get_lock()
    pool.map(process_page_wrapper, range(pool._processes))
    time.sleep(3)
    pool.close()
    pool.join()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [00:23<00:00, 12.63it/s]

# %%
parsed[50]
# Out:
# {'name': 'Crusader Kings III',
#  'image': 'https://img.gg.deals/15/37/f17d91ce13bd6cf6c3b2a62b8524b7670e8f_307xt176.jpg',
#  'market_url': 'https://gg.deals/redirect/51d0f5757a6a4112d131ea20389baee07cfacc08/?utm_source=games%2Fsingle',
#  'wishlist_count': '4311',
#  'alert_count': '542',
#  'owners_count': '2848',
#  'release_date': '01 Sep 2020',
#  'developer': 'Paradox Development Studio',
#  'metacritic_score': '91',
#  'user_score': '8.3',
#  'review_label': 'Very Positive',
#  'review_positive_pctg': '93',
#  'review_count': '48,988',
#  'genres': ['RPG', 'Simulation', 'Strategy'],
#  'tags': ['Strategy',
#   'RPG',
#   'Simulation',
#   'Grand Strategy',
#   'Medieval',
#   'Historical',
#   'Political',
#   'War',
#   'Management',
#   'Character Customization',
#   'Singleplayer',
#   'Choices Matter',
#   'Multiplayer',
#   'Sandbox',
#   'Real-Time with Pause',
#   'Moddable',
#   'Sexual Content',
#   'PvP',
#   'Nudity',
#   'Dating Sim'],
#  'features': ['Single-player',
#   'Online PvP',
#   'Steam Achievements',
#   'Steam Trading Cards',
#   'Steam Workshop',
#   'Steam Cloud',
#   'Remote Play on Tablet'],
#  'platforms': ['Windows',
#   'Mac',
#   'Linux',
#   'Steam Deck Playable',
#   'GeForce Now'],
#  'dlcs': ['/dlc/crusader-kings-iii-fashion-of-the-abbasid-court/',
#   '/dlc/crusader-kings-iii-expansion-1/',
#   '/dlc/crusader-kings-iii-flavor-pack-2/',
#   '/dlc/crusader-kings-iii-northern-lords/'],
#  'packs': ['/pack/crusader-kings-iii-royal-edition/'],
#  'price_history': [{'shop': 'Steam', 'ts': 1589476358000, 'price': 49.99},
#   {'shop': 'WinGameStore', 'ts': 31649000, 'price': 47.49},
#   {'shop': 'Gamesplanet US', 'ts': 50801000, 'price': 44.99},
#   {'shop': 'WinGameStore', 'ts': 86113000, 'price': 44.95},
#   {'shop': 'Fanatical', 'ts': 172834000, 'price': 43.99},
#   {'shop': 'WinGameStore', 'ts': 14250000, 'price': 42.99},
#   {'shop': 'Gamebillet', 'ts': 2063456000, 'price': 42.28},
#   {'shop': 'Indie Gala Store', 'ts': 5763077000, 'price': 39.99},
#   {'shop': 'WinGameStore', 'ts': 719938000, 'price': 39.49},
#   {'shop': 'WinGameStore', 'ts': 75540000, 'price': 39},
#   {'shop': '2Game', 'ts': 958002000, 'price': 35.9},
#   {'shop': 'WinGameStore', 'ts': 10606000, 'price': 39},
#   {'shop': 'Fanatical', 'ts': 6818271000, 'price': 35.99},
#   {'shop': 'Green Man Gaming', 'ts': 441000, 'price': 33.99},
#   {'shop': 'Indie Gala Store', 'ts': 3195000, 'price': 33.89},
#   {'shop': 'WinGameStore', 'ts': 7087000, 'price': 33.49},
#   {'shop': 'Indie Gala Store', 'ts': 40159000, 'price': 32.99},
#   {'shop': 'WinGameStore', 'ts': 24640000, 'price': 32.9},
#   {'shop': 'Indie Gala Store', 'ts': 496819000, 'price': 32.99},
#   {'shop': 'Fanatical', 'ts': 51284000, 'price': 33.49},
#   {'shop': 'WinGameStore', 'ts': 3396000, 'price': 38.95},
#   {'shop': 'Gamebillet', 'ts': 824177000, 'price': 35.97},
#   {'shop': 'Green Man Gaming', 'ts': 389278000, 'price': 33.99},
#   {'shop': 'Indie Gala Store', 'ts': 542775000, 'price': 33.49},
#   {'shop': 'WinGameStore', 'ts': 205163000, 'price': 32.99},
#   {'shop': 'Voidu', 'ts': 392415000, 'price': 31.99},
#   {'shop': 'Fanatical', 'ts': 531716000, 'price': 33.74},
#   {'shop': 'Green Man Gaming', 'ts': 116520000, 'price': 33.99},
#   {'shop': 'Voidu', 'ts': 108173000, 'price': 35.99},
#   {'shop': 'WinGameStore', 'ts': 35947000, 'price': 38.95},
#   {'shop': 'Indie Gala Store', 'ts': 953733000, 'price': 32.99},
#   {'shop': 'WinGameStore', 'ts': 615404000, 'price': 32.95},
#   {'shop': 'WinGameStore', 'ts': 25326000, 'price': 32.49},
#   {'shop': 'Indie Gala Store', 'ts': 41885000, 'price': 32.99},
#   {'shop': 'Voidu', 'ts': 202787000, 'price': 31.99},
#   {'shop': 'Allyouplay', 'ts': 736192000, 'price': 35.99},
#   {'shop': 'Voidu', 'ts': 88811000, 'price': 31.99},
#   {'shop': 'Green Man Gaming', 'ts': 345193000, 'price': 33.99},
#   {'shop': 'Gamebillet', 'ts': 669713000, 'price': 33.98},
#   {'shop': 'Indie Gala Store', 'ts': 295077000, 'price': 31.99},
#   {'shop': 'Gamebillet', 'ts': 7246000, 'price': 31.98},
#   {'shop': 'Indie Gala Store', 'ts': 388954000, 'price': 31.99},
#   {'shop': 'WinGameStore', 'ts': 251618000, 'price': 29.99},
#   {'shop': 'Gamebillet', 'ts': 10802000, 'price': 35.98},
#   {'shop': 'WinGameStore', 'ts': 230414000, 'price': 34.99},
#   {'shop': 'Gamebillet', 'ts': 108365000, 'price': 34.98},
#   {'shop': 'WinGameStore', 'ts': 230028000, 'price': 33.48},
#   {'shop': 'Gamebillet', 'ts': 260000, 'price': 33.47},
#   {'shop': 'WinGameStore', 'ts': 269751000, 'price': 32.99},
#   {'shop': 'Gamebillet', 'ts': 223000, 'price': 32.98},
#   {'shop': 'WinGameStore', 'ts': 14160000, 'price': 29.75},
#   {'shop': 'Gamebillet', 'ts': 251000, 'price': 29.74},
#   {'shop': 'WinGameStore', 'ts': 150947000, 'price': 29},
#   {'shop': 'Gamebillet', 'ts': 248000, 'price': 28.98},
#   {'shop': 'WinGameStore', 'ts': 10557000, 'price': 27.9},
#   {'shop': 'Gamebillet', 'ts': 3829000, 'price': 27.89},
#   {'shop': 'Gamebillet', 'ts': 162081000, 'price': 23.98},
#   {'shop': 'WinGameStore', 'ts': 266327000, 'price': 23.99},
#   {'shop': 'Gamebillet', 'ts': 3354000, 'price': 24.98},
#   {'shop': 'WinGameStore', 'ts': 180006000, 'price': 22.99},
#   {'shop': 'Gamebillet', 'ts': 238000, 'price': 22.98},
#   {'shop': 'Gamebillet', 'ts': 17998000, 'price': 24.79},
#   {'shop': 'Gamebillet', 'ts': 313215000, 'price': 24.49},
#   {'shop': 'WinGameStore', 'ts': 21627000, 'price': 24.5},
#   {'shop': 'WinGameStore', 'ts': 29037000, 'price': 29.75},
#   {'shop': 'Fanatical', 'ts': 31903000, 'price': 32.54},
#   {'shop': 'Green Man Gaming', 'ts': 223286000, 'price': 33.59},
#   {'shop': 'WinGameStore', 'ts': 122292000, 'price': 33.48},
#   {'shop': 'Gamebillet', 'ts': 86781000, 'price': 31.95},
#   {'shop': 'WinGameStore', 'ts': 510826000, 'price': 31.49},
#   {'shop': 'Gamebillet', 'ts': 245000, 'price': 31.39},
#   {'shop': 'Gamebillet', 'ts': 36033000, 'price': 31.48},
#   {'shop': 'Gamebillet', 'ts': 133199000, 'price': 34.98},
#   {'shop': 'WinGameStore', 'ts': 100529000, 'price': 33.99},
#   {'shop': 'Gamebillet', 'ts': 233000, 'price': 33.98},
#   {'shop': 'WinGameStore', 'ts': 334567000, 'price': 29.99},
#   {'shop': 'Gamebillet', 'ts': 221000, 'price': 29.98},
#   {'shop': 'WinGameStore', 'ts': 93377000, 'price': 28.99},
#   {'shop': 'Gamebillet', 'ts': 514000, 'price': 28.98},
#   {'shop': 'WinGameStore', 'ts': 1723877000, 'price': 25.99},
#   {'shop': 'Gamebillet', 'ts': 1008532000, 'price': 28.98},
#   {'shop': 'WinGameStore', 'ts': 481886000, 'price': 26.99},
#   {'shop': 'Gamebillet', 'ts': 4161000, 'price': 24.98},
#   {'shop': 'WinGameStore', 'ts': 334238000, 'price': 23.99},
#   {'shop': 'Gamebillet', 'ts': 18133000, 'price': 23.98},
#   {'shop': 'WinGameStore', 'ts': 53854000, 'price': 22.99},
#   {'shop': 'Gamebillet', 'ts': 3824000, 'price': 22.98},
#   {'shop': 'Gamebillet', 'ts': 230387000, 'price': 24.98},
#   {'shop': 'Gamebillet', 'ts': 7043000, 'price': 25.79},
#   {'shop': 'Indie Gala Store', 'ts': 46817000, 'price': 25.89},
#   {'shop': 'Gamebillet', 'ts': 7123000, 'price': 28.98},
#   {'shop': 'Gamebillet', 'ts': 1638204000, 'price': 25.89},
#   {'shop': 'Indie Gala Store', 'ts': 28947000, 'price': 24.99},
#   {'shop': 'Gamebillet', 'ts': 10587000, 'price': 24.95},
#   {'shop': 'Indie Gala Store', 'ts': 993618000, 'price': 24.99},
#   {'shop': 'Gamebillet', 'ts': 7260000, 'price': 27.95},
#   {'shop': 'WinGameStore', 'ts': 921388000, 'price': 26.99},
#   {'shop': 'Gamebillet', 'ts': 28864000, 'price': 26.98},
#   {'shop': 'WinGameStore', 'ts': 237530000, 'price': 25.99},
#   {'shop': 'Gamebillet', 'ts': 7273000, 'price': 25.98},
#   {'shop': 'WinGameStore', 'ts': 71931000, 'price': 22.95},
#   {'shop': 'Gamebillet', 'ts': 18066000, 'price': 25.48},
#   {'shop': 'Fanatical', 'ts': 216325000, 'price': 42.39},
#   {'shop': 'Gamebillet', 'ts': 252122000, 'price': 27.9},
#   {'shop': 'Fanatical', 'ts': 3052562000, 'price': 34.99},
#   {'shop': 'Fanatical', 'ts': 344482000, 'price': 32.54},
#   {'shop': 'WinGameStore', 'ts': 141594000, 'price': 32.49},
#   {'shop': 'WinGameStore', 'ts': 564852000, 'price': 27.95},
#   {'shop': 'Voidu', 'ts': 126461000, 'price': 35.99},
#   {'shop': 'Gamebillet', 'ts': 248218000, 'price': 37.9},
#   {'shop': 'Fanatical', 'ts': 932317000, 'price': 36.49},
#   {'shop': 'Gamebillet', 'ts': 50279000, 'price': 36.39},
#   {'shop': 'Gamebillet', 'ts': 295242000, 'price': 33.97},
#   {'shop': 'Gamebillet', 'ts': 259328000, 'price': 28.98},
#   {'shop': 'Gamebillet', 'ts': 338250000, 'price': 33.98},
#   {'shop': 'Gamebillet', 'ts': 1702786000, 'price': 34.98},
#   {'shop': 'WinGameStore', 'ts': 407388000, 'price': 32.49},
#   {'shop': 'Gamebillet', 'ts': 10189000, 'price': 32.48},
#   {'shop': 'Voidu', 'ts': 1054800000, 'price': 34.71},
#   {'shop': 'Green Man Gaming', 'ts': 1329079000, 'price': 33.59},
#   {'shop': 'WinGameStore', 'ts': 395789000, 'price': 32.49},
#   {'shop': 'Gamebillet', 'ts': 756233000, 'price': 34.7},
#   {'shop': 'Voidu', 'ts': 741143000, 'price': 33.99},
#   {'shop': 'Gamebillet', 'ts': 17000, 'price': 33.95},
#   {'shop': 'WinGameStore', 'ts': 770432000, 'price': 32.49},
#   {'shop': 'Gamebillet', 'ts': 14848000, 'price': 32.39},
#   {'shop': 'GamersGate', 'ts': 21002000, 'price': 31.32},
#   {'shop': 'Gamebillet', 'ts': 10696000, 'price': 31.29},
#   {'shop': 'Indie Gala Store', 'ts': 25312000, 'price': 29.99},
#   {'shop': 'Gamebillet', 'ts': 193000, 'price': 29.95},
#   {'shop': 'Fanatical', 'ts': 1159624000, 'price': 33.99},
#   {'shop': 'Gamebillet', 'ts': 420677000, 'price': 37.9},
#   {'shop': 'Newegg', 'ts': 1123149000, 'price': 35.99},
#   {'shop': 'Fanatical', 'ts': 4319000, 'price': 34.99},
#   {'shop': 'Green Man Gaming', 'ts': 564000, 'price': 27.46},
#   {'shop': 'Gamebillet', 'ts': 726042000, 'price': 27.45},
#   {'shop': 'Indie Gala Store', 'ts': 600882000, 'price': 26.99},
#   {'shop': 'Gamebillet', 'ts': 3631000, 'price': 26.95},
#   {'shop': 'WinGameStore', 'ts': 194306000, 'price': 24.99},
#   {'shop': 'Gamebillet', 'ts': 211000, 'price': 24.95},
#   {'shop': 'WinGameStore', 'ts': 96840000, 'price': 22.99},
#   {'shop': 'Gamebillet', 'ts': 154000, 'price': 22.95},
#   {'shop': 'Indie Gala Store', 'ts': 360194000, 'price': 26.99},
#   {'shop': 'Allyouplay', 'ts': 3529000, 'price': 35.99},
#   {'shop': 'Gamebillet', 'ts': 575000, 'price': 38.79},
#   {'shop': 'WinGameStore', 'ts': 114855000, 'price': 32.49},
#   {'shop': 'Gamebillet', 'ts': 89744000, 'price': 32.48},
#   {'shop': 'WinGameStore', 'ts': 35911000, 'price': 24.99},
#   {'shop': 'Gamebillet', 'ts': 565528000, 'price': 32.48},
#   {'shop': 'Gamebillet', 'ts': 6982000, 'price': 37.99},
#   {'shop': 'Green Man Gaming', 'ts': 360282000, 'price': 33.49},
#   {'shop': 'Gamebillet', 'ts': 773910000, 'price': 33.39},
#   {'shop': 'WinGameStore', 'ts': 68854000, 'price': 32.49},
#   {'shop': 'Gamebillet', 'ts': 10123000, 'price': 32.39},
#   {'shop': 'WinGameStore', 'ts': 281682000, 'price': 29.99},
#   {'shop': 'Gamebillet', 'ts': 161101000, 'price': 29.95},
#   {'shop': 'Gamebillet', 'ts': 853281000, 'price': 37.95},
#   {'shop': 'Fanatical', 'ts': 129644000, 'price': 35.99},
#   {'shop': 'Gamebillet', 'ts': 35877000, 'price': 35.95},
#   {'shop': 'Gamebillet', 'ts': 638165000, 'price': 38.95},
#   {'shop': 'WinGameStore', 'ts': 391695000, 'price': 32.49},
#   {'shop': 'Gamebillet', 'ts': 266146000, 'price': 28.95},
#   {'shop': 'Green Man Gaming', 'ts': 219936000, 'price': 28.47},
#   {'shop': 'Gamebillet', 'ts': 1296182000, 'price': 28.95},
#   {'shop': 'Gamebillet', 'ts': 467986000, 'price': 34.39},
#   {'shop': 'Humble Store', 'ts': 355004000, 'price': 27.49},
#   {'shop': 'Gamebillet', 'ts': 105221000, 'price': 34.39},
#   {'shop': 'Gamebillet', 'ts': 428880000, 'price': 34.39}]}

# %%
parsed[167]
# Out:
# {'name': 'Pillars of Eternity II: Deadfire',
#  'image': 'https://img.gg.deals/da/c9/2742ea6c8be597620effce70b4c1813c201a_307xt176.jpg',
#  'market_url': 'https://gg.deals/redirect/429b749aeccfbf24f6a51fe46058cfe5aa5dfde1/?utm_source=games%2Fsingle',
#  'wishlist_count': '4550',
#  'alert_count': '534',
#  'owners_count': '4452',
#  'release_date': '08 May 2018',
#  'developer': 'Obsidian Entertainment',
#  'metacritic_score': '88',
#  'user_score': '7.8',
#  'review_label': 'Very Positive',
#  'review_positive_pctg': '86',
#  'review_count': '10,265',
#  'genres': ['RPG'],
#  'tags': ['RPG',
#   'Party-Based RPG',
#   'Isometric',
#   'Story Rich',
#   'Fantasy',
#   'Singleplayer',
#   'CRPG',
#   'Character Customization',
#   'Choices Matter',
#   'Open World',
#   'Real-Time with Pause',
#   'Turn-Based',
#   'Adventure',
#   'Pirates',
#   'Nudity',
#   'Exploration',
#   'Great Soundtrack',
#   'Atmospheric',
#   'Romance',
#   'Female Protagonist'],
#  'features': ['Single-player',
#   'Steam Achievements',
#   'Steam Trading Cards',
#   'Steam Workshop',
#   'Steam Cloud',
#   'Remote Play on Tablet'],
#  'platforms': ['Windows', 'Mac', 'Linux', 'Steam Deck Playable'],
#  'dlcs': ['/dlc/pillars-of-eternity-ii-deadfire-obsidian-upgrade-dlc/',
#   '/dlc/pillars-of-eternity-ii-deadfire-soundtrack/',
#   '/dlc/pillars-of-eternity-ii-deadfire-season-pass/',
#   '/dlc/pillars-of-eternity-ii-deadfire-explorer-s-pack/'],
#  'packs': ['/pack/pillars-of-eternity-ii-deadfire-deluxe-edition/',
#   '/pack/pillars-of-eternity-collection/',
#   '/pack/pillars-of-eternity-ii-deadfire-obsidian-edition/',
#   '/pack/pillars-of-eternity-ii-deadfire-ultimate-edition/'],
#  'price_history': [{'shop': 'Gog.com', 'ts': 1510596716000, 'price': 99.99},
#   {'shop': 'Gog.com', 'ts': 6307001000, 'price': 49.99},
#   {'shop': 'GamersGate', 'ts': 51064000, 'price': 44.99},
#   {'shop': 'Fanatical', 'ts': 1749705000, 'price': 41.49},
#   {'shop': 'Fanatical', 'ts': 1159258000, 'price': 41.49},
#   {'shop': None, 'ts': 1, 'price': None},
#   {'shop': 'Fanatical', 'ts': 1794040999, 'price': 41.49},
#   {'shop': 'Fanatical', 'ts': 2579675000, 'price': 49.99},
#   {'shop': 'Fanatical', 'ts': 237656000, 'price': 41.49},
#   {'shop': 'Gamesplanet UK', 'ts': 276509000, 'price': 40.71},
#   {'shop': 'Fanatical', 'ts': 1049341000, 'price': 38.99},
#   {'shop': 'Fanatical', 'ts': 1431968000, 'price': 49.99},
#   {'shop': 'Origin', 'ts': 446233000, 'price': 49.99},
#   {'shop': 'Fanatical', 'ts': 1000, 'price': 38.99},
#   {'shop': 'DLGamer.com', 'ts': 780978000, 'price': 35.99},
#   {'shop': 'DLGamer.com', 'ts': 1902027000, 'price': 47.49},
#   {'shop': 'DLGamer.com', 'ts': 172672000, 'price': 35.99},
#   {'shop': 'DLGamer.com', 'ts': 197364000, 'price': 29.99},
#   {'shop': 'DLGamer.com', 'ts': 86346000, 'price': 24.99},
#   {'shop': 'DLGamer.com', 'ts': 1097981000, 'price': 47.49},
#   {'shop': 'DLGamer.com', 'ts': 690986000, 'price': 37.99},
#   {'shop': 'DLGamer.com', 'ts': 432212000, 'price': 47.49},
#   {'shop': 'Gog.com', 'ts': 190351000, 'price': 39.99},
#   {'shop': 'Gamesplanet UK', 'ts': 316481000, 'price': 35.74},
#   {'shop': 'Fanatical', 'ts': 123802000, 'price': 34.99},
#   {'shop': 'WinGameStore', 'ts': 250476000, 'price': 34.85},
#   {'shop': 'Gamesplanet UK', 'ts': 55345000, 'price': 34.45},
#   {'shop': 'Gamesplanet UK', 'ts': 173544000, 'price': 41.1},
#   {'shop': 'Green Man Gaming', 'ts': 888533000, 'price': 38.27},
#   {'shop': 'Gamesplanet UK', 'ts': 610285000, 'price': 41.1},
#   {'shop': 'Steam', 'ts': 2247946000, 'price': 32.99},
#   {'shop': 'DLGamer.com', 'ts': 265899000, 'price': 40.99},
#   {'shop': 'Gog.com', 'ts': 245274000, 'price': 32.99},
#   {'shop': 'DLGamer.com', 'ts': 542789000, 'price': 40.99},
#   {'shop': 'Gamebillet', 'ts': 184609000, 'price': 40.98},
#   {'shop': 'DLGamer.com', 'ts': 125536000, 'price': 37.49},
#   {'shop': 'Gamebillet', 'ts': 305628000, 'price': 40.98},
#   {'shop': 'Gamesplanet UK', 'ts': 248802000, 'price': 41.1},
#   {'shop': 'Humble Store', 'ts': 2491887000, 'price': 39.59},
#   {'shop': 'Gog.com', 'ts': 502827000, 'price': 32.99},
#   {'shop': 'Gamesplanet DE', 'ts': 415291000, 'price': 29.46},
#   {'shop': 'Gamesplanet UK', 'ts': 52000, 'price': 27.9},
#   {'shop': 'Gamesplanet FR', 'ts': 568167000, 'price': 29.46},
#   {'shop': 'Fanatical', 'ts': 314000, 'price': 32.99},
#   {'shop': 'GamersGate UK', 'ts': 271758000, 'price': 26.89},
#   {'shop': 'GamersGate', 'ts': 338371000, 'price': 32},
#   {'shop': 'GamersGate UK', 'ts': 194000, 'price': 38.29},
#   {'shop': 'GamersGate', 'ts': 3385000, 'price': 38.4},
#   {'shop': 'Gamesplanet UK', 'ts': 101000, 'price': 39.93},
#   {'shop': 'Gog.com', 'ts': 303980000, 'price': 32.99},
#   {'shop': 'GamersGate UK', 'ts': 1760158000, 'price': 26.89},
#   {'shop': 'GamersGate', 'ts': 348410000, 'price': 32},
#   {'shop': 'Gamebillet', 'ts': 73000, 'price': 39.49},
#   {'shop': 'Humble Store', 'ts': 325478000, 'price': 32.99},
#   {'shop': 'Gamesplanet DE', 'ts': 881483000, 'price': 28.42},
#   {'shop': 'Gamesplanet FR', 'ts': 24000, 'price': 28.49},
#   {'shop': 'Gog.com', 'ts': 603574000, 'price': 32.99},
#   {'shop': 'Gamesplanet UK', 'ts': 259104000, 'price': 40.84},
#   {'shop': 'Steam', 'ts': 416971000, 'price': 32.99},
#   {'shop': 'Steam', 'ts': 604040000, 'price': 39.59},
#   {'shop': 'Gamebillet', 'ts': 5337000, 'price': 40.39},
#   {'shop': 'Gog.com', 'ts': 3261448000, 'price': 32.99},
#   {'shop': 'Fanatical', 'ts': 10191000, 'price': 24.99},
#   {'shop': 'Gog.com', 'ts': 169152000, 'price': 32.99},
#   {'shop': 'Fanatical', 'ts': 458064000, 'price': 32.99},
#   {'shop': 'Gamesplanet UK', 'ts': 201121000, 'price': 40.75},
#   {'shop': 'Gamesplanet DE', 'ts': 90683000, 'price': 40.73},
#   {'shop': 'Gamesplanet DE', 'ts': 4000, 'price': 34.06},
#   {'shop': 'Gamesplanet UK', 'ts': 57000, 'price': 28.38},
#   {'shop': 'Gamesplanet US', 'ts': 432375000, 'price': 26.99},
#   {'shop': 'Gamesplanet DE', 'ts': 95000, 'price': 26.95},
#   {'shop': 'Gamesplanet UK', 'ts': 24000, 'price': 26.06},
#   {'shop': 'Gamesplanet FR', 'ts': 172466000, 'price': 26.91},
#   {'shop': 'Gamesplanet US', 'ts': 36000, 'price': 26.99},
#   {'shop': 'WinGameStore', 'ts': 486000, 'price': 40.99},
#   {'shop': 'GamersGate UK', 'ts': 266638000, 'price': 38.88},
#   {'shop': 'WinGameStore', 'ts': 44767000, 'price': 32.99},
#   {'shop': 'Gamebillet', 'ts': 7452000, 'price': 32.79},
#   {'shop': 'DLGamer.com', 'ts': 87061000, 'price': 24.99},
#   {'shop': 'Gamebillet', 'ts': 420504000, 'price': 23.69},
#   {'shop': 'WinGameStore', 'ts': 151032000, 'price': 23.65},
#   {'shop': 'Gamebillet', 'ts': 7363000, 'price': 23.59},
#   {'shop': 'WinGameStore', 'ts': 6980000, 'price': 23.55},
#   {'shop': 'DLGamer.com', 'ts': 10805000, 'price': 24.99},
#   {'shop': 'Dreamgame US', 'ts': 8060000, 'price': 33.02},
#   {'shop': 'GamersGate', 'ts': 168559000, 'price': 29.69},
#   {'shop': 'GamersGate UK', 'ts': 3421000, 'price': 25.27},
#   {'shop': 'GamersGate', 'ts': 339124000, 'price': 29.69},
#   {'shop': 'Dreamgame US', 'ts': 105000, 'price': 33.02},
#   {'shop': 'Fanatical', 'ts': 578754000, 'price': 32.99},
#   {'shop': 'Gog.com', 'ts': 572743000, 'price': 32.99},
#   {'shop': 'Humble Store', 'ts': 226740000, 'price': 32.99},
#   {'shop': 'GamersGate UK', 'ts': 694529000, 'price': 24.8},
#   {'shop': 'GamersGate', 'ts': 345746000, 'price': 29.69},
#   {'shop': 'Humble Store', 'ts': 180000, 'price': 32.99},
#   {'shop': 'Dreamgame US', 'ts': 326135000, 'price': 33.02},
#   {'shop': 'Gog.com', 'ts': 243074000, 'price': 24.99},
#   {'shop': 'Dreamgame US', 'ts': 1587745000, 'price': 33.02},
#   {'shop': 'Fanatical', 'ts': 150320000, 'price': 19.99},
#   {'shop': 'Fanatical', 'ts': 171872000, 'price': 24.99},
#   {'shop': 'Fanatical', 'ts': 282810000, 'price': 22.49},
#   {'shop': 'Gog.com', 'ts': 981680000, 'price': 24.99},
#   {'shop': 'Steam', 'ts': 227310000, 'price': 24.99},
#   {'shop': 'Steam', 'ts': 93782000, 'price': 26.99},
#   {'shop': 'Dreamgame US', 'ts': 2039000, 'price': 33.02},
#   {'shop': 'Green Man Gaming', 'ts': 1239860000, 'price': 25},
#   {'shop': 'Green Man Gaming', 'ts': 198141000, 'price': 22.5},
#   {'shop': 'Dreamgame US', 'ts': 460392000, 'price': 33.02},
#   {'shop': 'Gamesplanet US', 'ts': 374654000, 'price': 29.99},
#   {'shop': 'Gamesplanet US', 'ts': 1000, 'price': 25},
#   {'shop': 'Gamesplanet UK', 'ts': 663000, 'price': 19.86},
#   {'shop': 'Gamesplanet UK', 'ts': 431247000, 'price': 18.03},
#   {'shop': 'Gamesplanet FR', 'ts': 173605000, 'price': 20.16},
#   {'shop': 'Gamesplanet DE', 'ts': 5000, 'price': 20.16},
#   {'shop': 'Steam', 'ts': 2892000, 'price': 24.99},
#   {'shop': 'Steam', 'ts': 29456000, 'price': 29.99},
#   {'shop': 'Dreamgame US', 'ts': 121000, 'price': 33.02},
#   {'shop': 'Fanatical', 'ts': 165533000, 'price': 22.49},
#   {'shop': 'GamersGate UK', 'ts': 978785000, 'price': 18.88},
#   {'shop': 'GamersGate UK', 'ts': 1000, 'price': 14.67},
#   {'shop': 'GamersGate', 'ts': 150340000, 'price': 18.19},
#   {'shop': 'GamersGate UK', 'ts': 144000, 'price': 19.56},
#   {'shop': 'Gog.com', 'ts': 246328000, 'price': 24.99},
#   {'shop': 'Fanatical', 'ts': 604630000, 'price': 24.99},
#   {'shop': 'Gamebillet', 'ts': 495322000, 'price': 32.98},
#   {'shop': 'Green Man Gaming', 'ts': 356685000, 'price': 25},
#   {'shop': 'Steam', 'ts': 716648000, 'price': 24.99},
#   {'shop': 'Steam', 'ts': 259233000, 'price': 26.99},
#   {'shop': 'Steam', 'ts': 9799000, 'price': 29.99},
#   {'shop': 'Gamesplanet UK', 'ts': 8318000, 'price': 38.25},
#   {'shop': 'Fanatical', 'ts': 842002000, 'price': 16.99},
#   {'shop': 'Gamebillet', 'ts': 187093000, 'price': 38.19},
#   {'shop': 'Gog.com', 'ts': 406844000, 'price': 24.99},
#   {'shop': 'Gamesplanet DE', 'ts': 586913000, 'price': 20.07},
#   {'shop': 'Gamesplanet DE', 'ts': 9000, 'price': 18.96},
#   {'shop': 'Gamesplanet UK', 'ts': 12000, 'price': 16.66},
#   {'shop': 'Gamesplanet FR', 'ts': 608439000, 'price': 18.83},
#   {'shop': 'Green Man Gaming', 'ts': 3000, 'price': 21.25},
#   {'shop': 'Gamebillet', 'ts': 368019000, 'price': 17.59},
#   {'shop': 'WinGameStore', 'ts': 628940000, 'price': 17.6},
#   {'shop': 'WinGameStore', 'ts': 7029000, 'price': 22.65},
#   {'shop': 'WinGameStore', 'ts': 1000, 'price': 24.85},
#   {'shop': 'Humble Store', 'ts': 1000, 'price': 24.99},
#   {'shop': 'Gamesplanet UK', 'ts': 497002000, 'price': 40.56},
#   {'shop': 'Gamebillet', 'ts': 439296000, 'price': 32.39},
#   {'shop': 'GamersGate', 'ts': 100677000, 'price': 25},
#   {'shop': 'GamersGate UK', 'ts': 3445000, 'price': 21.18},
#   {'shop': 'GamersGate UK', 'ts': 339482000, 'price': 21.2},
#   {'shop': 'Fanatical', 'ts': 24114000, 'price': 22.49},
#   {'shop': 'Fanatical', 'ts': 732467000, 'price': 24.99},
#   {'shop': 'Gamebillet', 'ts': 53640000, 'price': 32.39},
#   {'shop': 'Steam', 'ts': 294572000, 'price': 24.99},
#   {'shop': 'Steam', 'ts': 173485000, 'price': 25.5},
#   {'shop': 'Gamebillet', 'ts': 168000, 'price': 35.99},
#   {'shop': 'Gog.com', 'ts': 158273000, 'price': 24.99},
#   {'shop': 'Gamesplanet US', 'ts': 413159000, 'price': 23.99},
#   {'shop': 'Gamesplanet US', 'ts': 2000, 'price': 21.99},
#   {'shop': 'Gamesplanet UK', 'ts': 262000, 'price': 18.73},
#   {'shop': 'GamersGate UK', 'ts': 604629000, 'price': 21.41},
#   {'shop': 'Fanatical', 'ts': 312890000, 'price': 22.49},
#   {'shop': 'Gamebillet', 'ts': 721178000, 'price': 35.99},
#   {'shop': 'WinGameStore', 'ts': 225414000, 'price': 39.98},
#   {'shop': 'Humble Store', 'ts': 294596000, 'price': 24.99},
#   {'shop': 'Fanatical', 'ts': 374879000, 'price': 22.49},
#   {'shop': 'Green Man Gaming', 'ts': 757293000, 'price': 21.25},
#   {'shop': 'Gamebillet', 'ts': 1100650000, 'price': 34.99},
#   {'shop': 'Fanatical', 'ts': 111429000, 'price': 31.49},
#   {'shop': 'Gamebillet', 'ts': 61163000, 'price': 31.48},
#   {'shop': 'Gog.com', 'ts': 32677000, 'price': 23.99},
#   {'shop': 'WinGameStore', 'ts': 259142000, 'price': 29.99},
#   {'shop': 'GamersGate UK', 'ts': 215604000, 'price': 29.36},
#   {'shop': 'GamersGate', 'ts': 3722000, 'price': 23.99},
#   {'shop': 'GamersGate UK', 'ts': 3474000, 'price': 23.47},
#   {'shop': 'GamersGate UK', 'ts': 329037000, 'price': 23.48},
#   {'shop': 'GamersGate', 'ts': 16562000, 'price': 23.99},
#   {'shop': 'Fanatical', 'ts': 176000, 'price': 29.92},
#   {'shop': 'WinGameStore', 'ts': 21621000, 'price': 29.99},
#   {'shop': 'Humble Store', 'ts': 1290368000, 'price': 23.99},
#   {'shop': 'Gamebillet', 'ts': 228852000, 'price': 23.74},
#   {'shop': 'Gamebillet', 'ts': 245199000, 'price': 19.39},
#   {'shop': 'Gamebillet', 'ts': 269572000, 'price': 19.59},
#   {'shop': 'Green Man Gaming', 'ts': 130405000, 'price': 17},
#   {'shop': 'Gog.com', 'ts': 391786000, 'price': 19.99},
#   {'shop': 'Steam', 'ts': 1084350000, 'price': 23.99},
#   {'shop': 'Steam', 'ts': 100962000, 'price': 29.99},
#   {'shop': 'Gamebillet', 'ts': 289000, 'price': 32.49},
#   {'shop': 'Fanatical', 'ts': 513740000, 'price': 21.99},
#   {'shop': 'Green Man Gaming', 'ts': 287959000, 'price': 19.68},
#   {'shop': 'Gamesplanet US', 'ts': 460882000, 'price': 18.99},
#   {'shop': 'Gamesplanet UK', 'ts': 117000, 'price': 17.83},
#   {'shop': 'Green Man Gaming', 'ts': 86418000, 'price': 20.39},
#   {'shop': 'Gamesplanet US', 'ts': 262740000, 'price': 18.99},
#   {'shop': 'Gamesplanet UK', 'ts': 450000, 'price': 17.77},
#   {'shop': 'Green Man Gaming', 'ts': 83240000, 'price': 20.39},
#   {'shop': 'Fanatical', 'ts': 917494000, 'price': 29.39},
#   {'shop': 'Gamebillet', 'ts': 322189000, 'price': 32.49},
#   {'shop': 'Steam', 'ts': 693293000, 'price': 19.99},
#   {'shop': 'Fanatical', 'ts': 688245000, 'price': 19.99},
#   {'shop': 'Gog.com', 'ts': 657191000, 'price': 19.99},
#   {'shop': 'GamersGate UK', 'ts': 320176000, 'price': 18.83},
#   {'shop': 'Gog.com', 'ts': 342027000, 'price': 19.99},
#   {'shop': 'Gamebillet', 'ts': 915577000, 'price': 28.98},
#   {'shop': 'Steam', 'ts': 886746000, 'price': 19.99},
#   {'shop': 'Steam', 'ts': 1209976000, 'price': 23.99},
#   {'shop': 'Gamebillet', 'ts': 3298000, 'price': 28.98},
#   {'shop': 'GamersGate UK', 'ts': 876013000, 'price': 19.09},
#   {'shop': 'Gamesplanet UK', 'ts': 289857000, 'price': 19.61},
#   {'shop': 'Gamesplanet US', 'ts': 780152000, 'price': 15.99},
#   {'shop': 'Gamesplanet UK', 'ts': 186000, 'price': 15.7},
#   {'shop': 'Gamesplanet FR', 'ts': 169916000, 'price': 18.82},
#   {'shop': 'Gog.com', 'ts': 15000, 'price': 19.99},
#   {'shop': 'Humble Store', 'ts': 32530000, 'price': 19.99},
#   {'shop': 'Gamebillet', 'ts': 602775000, 'price': 28.98},
#   {'shop': 'Fanatical', 'ts': 342048000, 'price': 14.79},
#   {'shop': 'Green Man Gaming', 'ts': 659221000, 'price': 17},
#   {'shop': 'Gamebillet', 'ts': 554489000, 'price': 16.98},
#   {'shop': 'Humble Store', 'ts': 626139000, 'price': 19.99},
#   {'shop': 'Gamebillet', 'ts': 498312000, 'price': 28.95},
#   {'shop': 'GamersGate', 'ts': 542021000, 'price': 20},
#   {'shop': 'Steam', 'ts': 62494000, 'price': 19.99},
#   {'shop': 'Gog.com', 'ts': 399123000, 'price': 19.99},
#   {'shop': 'Gamebillet', 'ts': 535697000, 'price': 28.95},
#   {'shop': 'GamersGate', 'ts': 1162694000, 'price': 20},
#   {'shop': 'Steam', 'ts': 62000000, 'price': 19.99},
#   {'shop': 'Fanatical', 'ts': 513813000, 'price': 19.79},
#   {'shop': 'Steam', 'ts': 82753000, 'price': 19.99},
#   {'shop': 'Steam', 'ts': 8938000, 'price': 23.99},
#   {'shop': 'Gamebillet', 'ts': 313000, 'price': 28.95},
#   {'shop': 'Gog.com', 'ts': 592532000, 'price': 19.99},
#   {'shop': 'Humble Store', 'ts': 604766000, 'price': 19.99},
#   {'shop': 'Fanatical', 'ts': 183238000, 'price': 17.99},
#   {'shop': 'Gamebillet', 'ts': 1264088000, 'price': 28.95},
#   {'shop': 'Humble Store', 'ts': 174737000, 'price': 19.99},
#   {'shop': 'Fanatical', 'ts': 30179000, 'price': 17.59},
#   {'shop': 'GamersGate', 'ts': 917591000, 'price': 17.6},
#   {'shop': 'Gamebillet', 'ts': 64995000, 'price': 28.95},
#   {'shop': 'WinGameStore', 'ts': 489665000, 'price': 28.99},
#   {'shop': 'GAMESLOAD', 'ts': 191683000, 'price': 20},
#   {'shop': 'GAMESLOAD', 'ts': 53619000, 'price': 16.39},
#   {'shop': 'Gamebillet', 'ts': 3110000, 'price': 16.38},
#   {'shop': 'WinGameStore', 'ts': 14151000, 'price': 15.99},
#   {'shop': 'Gamebillet', 'ts': 202000, 'price': 15.98},
#   {'shop': 'Gog.com', 'ts': 619248000, 'price': 15.99},
#   {'shop': 'Humble Store', 'ts': 1437280000, 'price': 19.99},
#   {'shop': 'Gamebillet', 'ts': 294269000, 'price': 17.95},
#   {'shop': 'GAMESLOAD', 'ts': 50928000, 'price': 16.39},
#   {'shop': 'Gamebillet', 'ts': 3080000, 'price': 16.33},
#   {'shop': 'WinGameStore', 'ts': 6985000, 'price': 15.99},
#   {'shop': 'Gamebillet', 'ts': 491000, 'price': 15.95},
#   {'shop': 'WinGameStore', 'ts': 359541000, 'price': 15.29},
#   {'shop': 'Gamebillet', 'ts': 129000, 'price': 15.28},
#   {'shop': 'WinGameStore', 'ts': 266432000, 'price': 15.29},
#   {'shop': 'Fanatical', 'ts': 3424000, 'price': 19.99},
#   {'shop': 'Gog.com', 'ts': 234491000, 'price': 19.99},
#   {'shop': 'Humble Store', 'ts': 594017000, 'price': 19.99},
#   {'shop': 'Gamebillet', 'ts': 622880000, 'price': 28.95},
#   {'shop': 'Fanatical', 'ts': 338465000, 'price': 17.99},
#   {'shop': 'Gamebillet', 'ts': 1201922000, 'price': 16.38},
#   {'shop': 'WinGameStore', 'ts': 17815000, 'price': 15.89},
#   {'shop': 'Gamebillet', 'ts': 191000, 'price': 15.88},
#   {'shop': 'WinGameStore', 'ts': 615606000, 'price': 15.89},
#   {'shop': 'GamersGate', 'ts': 3417000, 'price': 20},
#   {'shop': 'Gamebillet', 'ts': 176836000, 'price': 28.95},
#   {'shop': 'Fanatical', 'ts': 316809000, 'price': 19.79},
#   {'shop': 'Fanatical', 'ts': 86261000, 'price': 17.99},
#   {'shop': 'Fanatical', 'ts': 919163000, 'price': 19.79},
#   {'shop': 'GamersGate', 'ts': 27354000, 'price': 19.8},
#   {'shop': 'Gamesplanet US', 'ts': 234568000, 'price': 16.99},
#   {'shop': 'Gamesplanet UK', 'ts': 604867000, 'price': 17.52},
#   {'shop': 'Gog.com', 'ts': 280000, 'price': 19.99},
#   {'shop': 'Fanatical', 'ts': 543012000, 'price': 17.99},
#   {'shop': 'Gamebillet', 'ts': 659304000, 'price': 28.95},
#   {'shop': 'Gamesplanet US', 'ts': 608177000, 'price': 19.99},
#   {'shop': 'Gamesplanet US', 'ts': 172584000, 'price': 15.99},
#   {'shop': 'Gamesplanet UK', 'ts': 86555000, 'price': 16.57},
#   {'shop': 'Gamesplanet FR', 'ts': 300000, 'price': 19.14},
#   {'shop': 'Gamesplanet US', 'ts': 8000, 'price': 19.99},
#   {'shop': 'Fanatical', 'ts': 287150000, 'price': 17.99},
#   {'shop': 'Gamesplanet US', 'ts': 234758000, 'price': 15.99},
#   {'shop': 'Gamesplanet UK', 'ts': 86736000, 'price': 16.64},
#   {'shop': 'Gamesplanet FR', 'ts': 1619000, 'price': 19.34},
#   {'shop': 'Humble Store', 'ts': 10000, 'price': 19.99},
#   {'shop': 'Gamebillet', 'ts': 26692000, 'price': 28.95},
#   {'shop': 'Steam', 'ts': 1296889000, 'price': 11.99},
#   {'shop': 'Steam', 'ts': 604908000, 'price': 14.99},
#   {'shop': 'Fanatical', 'ts': 260000, 'price': 17.99},
#   {'shop': 'GamersGate', 'ts': 1172124000, 'price': 20},
#   {'shop': 'Gamebillet', 'ts': 485795000, 'price': 28.95},
#   {'shop': 'Gog.com', 'ts': 227541000, 'price': 19.99},
#   {'shop': 'Gamesplanet US', 'ts': 759246000, 'price': 15.99},
#   {'shop': 'Fanatical', 'ts': 605098000, 'price': 17.99},
#   {'shop': 'Fanatical', 'ts': 526014000, 'price': 16.19},
#   {'shop': 'Fanatical', 'ts': 569113000, 'price': 17.99},
#   {'shop': 'Steam', 'ts': 25400000, 'price': 19.99},
#   {'shop': 'Humble Store', 'ts': 122811000, 'price': 19.99},
#   {'shop': 'Gamebillet', 'ts': 603137000, 'price': 28.95},
#   {'shop': 'Steam', 'ts': 1037883000, 'price': 14.99},
#   {'shop': 'Gamebillet', 'ts': 172693000, 'price': 28.95},
#   {'shop': 'Fanatical', 'ts': 254842000, 'price': 17.99},
#   {'shop': 'Fanatical', 'ts': 600456000, 'price': 15.99},
#   {'shop': 'Fanatical', 'ts': 201175000, 'price': 14.39},
#   {'shop': 'Fanatical', 'ts': 346815000, 'price': 15.99},
#   {'shop': 'Gamesplanet US', 'ts': 319374000, 'price': 19.99},
#   {'shop': 'Gamesplanet US', 'ts': 148879000, 'price': 15.99},
#   {'shop': 'Gamesplanet UK', 'ts': 174291000, 'price': 16.35},
#   {'shop': 'Gamesplanet FR', 'ts': 23000, 'price': 18.71},
#   {'shop': 'Gamesplanet DE', 'ts': 21000, 'price': 18.71},
#   {'shop': 'GAMESLOAD', 'ts': 19784000, 'price': 17.99},
#   {'shop': 'Gamebillet', 'ts': 294617000, 'price': 16.99},
#   {'shop': 'Fanatical', 'ts': 658629000, 'price': 14.99},
#   {'shop': 'GamersGate', 'ts': 169131000, 'price': 17.79},
#   {'shop': 'Fanatical', 'ts': 90867000, 'price': 16.99},
#   {'shop': 'Fanatical', 'ts': 169929000, 'price': 17.99},
#   {'shop': 'Gamebillet', 'ts': 229166000, 'price': 28.95},
#   {'shop': 'Steam', 'ts': 1421030000, 'price': 19.99},
#   {'shop': 'Steam', 'ts': 605181000, 'price': 23.99},
#   {'shop': 'Gamebillet', 'ts': 214000, 'price': 28.95},
#   {'shop': 'Humble Store', 'ts': 345098000, 'price': 19.99},
#   {'shop': 'GamersGate', 'ts': 191658000, 'price': 17.79},
#   {'shop': 'GamersGate', 'ts': 140147000, 'price': 16.01},
#   {'shop': 'Gamebillet', 'ts': 461041000, 'price': 28.95},
#   {'shop': 'Fanatical', 'ts': 237340000, 'price': 17.99},
#   {'shop': 'Steam', 'ts': 702949000, 'price': 14.99},
#   {'shop': 'Steam', 'ts': 6069000, 'price': 9.99},
#   {'shop': 'Steam', 'ts': 342918000, 'price': 14.99},
#   {'shop': 'Gamebillet', 'ts': 1107000, 'price': 28.95},
#   {'shop': 'GamersGate', 'ts': 185838000, 'price': 8.89},
#   {'shop': 'Gamebillet', 'ts': 341868000, 'price': 28.95},
#   {'shop': 'GAMESLOAD', 'ts': 382227000, 'price': 20},
#   {'shop': 'WinGameStore', 'ts': 27754000, 'price': 19.99},
#   {'shop': 'GAMESLOAD', 'ts': 335553000, 'price': 16.99},
#   {'shop': 'Green Man Gaming', 'ts': 126456000, 'price': 12},
#   {'shop': 'Green Man Gaming', 'ts': 1000, 'price': 8},
#   {'shop': 'Gamebillet', 'ts': 132191000, 'price': 7.98},
#   {'shop': 'Green Man Gaming', 'ts': 633625000, 'price': 8},
#   {'shop': 'GamersGate', 'ts': 446995000, 'price': 8.89},
#   {'shop': 'Gamebillet', 'ts': 334972000, 'price': 28.95},
#   {'shop': 'Fanatical', 'ts': 149057000, 'price': 27.04},
#   {'shop': 'Humble Store', 'ts': 316853000, 'price': 14.99},
#   {'shop': 'Gamesplanet DE', 'ts': 142686000, 'price': 9.62},
#   {'shop': 'Gamesplanet UK', 'ts': 59000, 'price': 8.48},
#   {'shop': 'Fanatical', 'ts': 3149000, 'price': 7.99},
#   {'shop': 'Fanatical', 'ts': 298366000, 'price': 7.59},
#   {'shop': 'Fanatical', 'ts': 909075000, 'price': 7.99},
#   {'shop': 'Gamebillet', 'ts': 386739000, 'price': 7.98},
#   {'shop': 'DLGamer.com', 'ts': 644773000, 'price': 10},
#   {'shop': 'WinGameStore', 'ts': 10795000, 'price': 28.99},
#   {'shop': 'Fanatical', 'ts': 917507000, 'price': 7.99},
#   {'shop': 'GamersGate', 'ts': 1695617000, 'price': 8.49},
#   {'shop': 'Gog.com', 'ts': 575632000, 'price': 9.99},
#   {'shop': 'WinGameStore', 'ts': 51982000, 'price': 28.99},
#   {'shop': 'Green Man Gaming', 'ts': 294355000, 'price': 8},
#   {'shop': 'WinGameStore', 'ts': 950701000, 'price': 28.99},
#   {'shop': 'GamersGate', 'ts': 172793000, 'price': 8.49},
#   {'shop': 'Fanatical', 'ts': 349400000, 'price': 8.39},
#   {'shop': 'Fanatical', 'ts': 1409820000, 'price': 11.39},
#   {'shop': 'WinGameStore', 'ts': 31472000, 'price': 28.99},
#   {'shop': 'Gog.com', 'ts': 1193247000, 'price': 9.99},
#   {'shop': 'GamersGate', 'ts': 36106000, 'price': 8.49},
#   {'shop': 'Fanatical', 'ts': 521903000, 'price': 7.99},
#   {'shop': 'Gamesplanet UK', 'ts': 1066149000, 'price': 9.43},
#   {'shop': 'Gamesplanet DE', 'ts': 431551000, 'price': 8.97},
#   {'shop': 'Gamesplanet UK', 'ts': 157000, 'price': 8.02},
#   {'shop': 'Gamesplanet US', 'ts': 178245000, 'price': 8.5},
#   {'shop': 'Gamesplanet FR', 'ts': 11000, 'price': 8.97},
#   {'shop': 'Gamesplanet DE', 'ts': 13000, 'price': 8.97},
#   {'shop': 'WinGameStore', 'ts': 5000, 'price': 28.99},
#   {'shop': 'Fanatical', 'ts': 570561000, 'price': 7.99},
#   {'shop': 'Fanatical', 'ts': 575966000, 'price': 7.99}]}
